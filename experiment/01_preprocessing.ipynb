# %%
# !pip install rank-bm25 -qq

# %%
import os
import pickle
import asyncio
import numpy as np
import pandas as pd
from tqdm import tqdm
from dotenv import load_dotenv
from typing import List, Dict, Any, Tuple, Optional
from tqdm.asyncio import tqdm_asyncio
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor

from datasets import load_dataset

from pydantic import BaseModel, Field
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser

from rank_bm25 import BM25Okapi

import warnings
load_dotenv()
warnings.filterwarnings("ignore")

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## 1. Document Loading

# %%
document_df = pd.read_parquet("data/document.parquet")
document_df.head()
# Out:
#    docno                      Date  \
# 0      0 2023-12-16 22:00:00+00:00
# 1      1 2023-12-16 22:00:00+00:00
# 2      2 2023-12-16 21:00:00+00:00
# 3      3 2023-12-16 21:00:00+00:00
# 4      4 2023-12-16 21:00:00+00:00
#
#                                        Article_title Stock_symbol  \
# 0  My 6 Largest Portfolio Holdings Heading Into 2...         AAPL
# 1  Brokers Suggest Investing in Apple (AAPL): Rea...         AAPL
# 2                      Company News for Dec 19, 2023         AAPL
# 3  NVIDIA (NVDA) Up 243% YTD: Will It Carry Momen...         AAPL
# 4  Pre-Market Most Active for Dec 19, 2023 : BMY,...         AAPL
#
#                                                  Url  \
# 0  https://www.nasdaq.com/articles/my-6-largest-p...
# 1  https://www.nasdaq.com/articles/brokers-sugges...
# 2  https://www.nasdaq.com/articles/company-news-f...
# 3  https://www.nasdaq.com/articles/nvidia-nvda-up...
# 4  https://www.nasdaq.com/articles/pre-market-mos...
#
#                                              Article  \
# 0  After an absolute disaster of a year in 2022, ...
# 1  When deciding whether to buy, sell, or hold a ...
# 2  Shares of Apple Inc. AAPL lost 0.9% on China’s...
# 3  NVIDIA Corporation NVDA has witnessed a remark...
# 4  The NASDAQ 100 Pre-Market Indicator is up 10.1...
#
#                                     Textrank_summary
# 0  3: Apple There's little question that Apple (N...
# 1  Let's take a look at what these Wall Street he...
# 2  Click to get this free report Apple Inc. (AAPL...
# 3  Other Stocks in the $1T Club Apart from NVIDIA...
# 4  Apple Inc. (AAPL) is +0.86 at $196.75, with 1,...

# %% [markdown]
# ## 2. Query Generator

# %%
QUERY_PROMPT_TEMPLATE = """
You are a query generation assistant for a financial news retrieval system. Your task is to generate natural and conversational search queries based on a given financial news article. These queries should mimic the style of queries humans would type into Google Search to find information related to the article.

Input:
- Document: {document}
- Number of Queries: {num_queries}

Instructions:
1. Focus on creating queries that are concise, natural, and written in a conversational style.
2. Reflect the key topics, entities (e.g., companies, individuals, financial instruments), or events in the article with the corresponding date in document.
3. Ensure the queries are relevant and diverse by covering different aspects of the article.
4. Avoid making the queries too specific by using niche or overly professional terms.
5. Periodically, use human keyword like "Best", "Top" to make the queries more engaging.
6. Avoid using word "today". If you create query that require timedate event, attend to the date in the document but make it wisely (either monthly for general event or explicit date for specific event)

Format each query as a standalone search phrase that feels natural for a human to type into Google.

Output:
{format_instructions}
"""

class QueryResponse(BaseModel):
    queries: List[str] = Field(description="a list of generated queries from response")

class QueryGenerator:
    def __init__(self, model: ChatOpenAI, parser: str, prompt: str):
        self.model = model
        self.prompt = prompt
        self.parser = JsonOutputParser(pydantic_object=parser)

    def __call(self, document: str, num_queries: int = 5) -> QueryResponse:
        prompt = PromptTemplate(
            template=self.prompt,
            input_variables=["document", "num_queries"],
            partial_variables={"format_instructions": self.parser.get_format_instructions()}
        )

        chain = prompt | self.model | self.parser
        response = chain.invoke({"document": document, "num_queries": num_queries})
        return response
    
    def generate_queries(self, docno: int, document: str, num_queries: int = 5) -> Tuple[int, QueryResponse]:
        response = self.__call(document=document, num_queries=num_queries)
        return docno, response

# Usage
query_generator = QueryGenerator(
    model=ChatOpenAI(model="gpt-4o-mini", temperature=0.5),
    parser=QueryResponse,
    prompt=QUERY_PROMPT_TEMPLATE
)

print(document_df["Article"][0])
query_generator.generate_queries(docno=0, document=document_df["Article"][0], num_queries=3)
# Out:
# After an absolute disaster of a year in 2022, the stock market appears to have turned the corner. Each of the major market indexes has gained more than 20% from their respective trough. Perhaps more importantly, the S&P 500 and the Nasdaq Composite are within striking distance of new highs, which will check the final box marking the start of a new bull market.
# Closing out the old and ringing in the new is a great time for examination, and one of the places I start is with my portfolio. A review of my top investments and how they came to be that way can offer valuable insight for the future.
# Here's a look at my six largest holdings heading into 2024 (as of the market close on Dec. 15) and the incredibly valuable lesson I learned from each one.
# Image source: Getty Images.
# No. 6: Nvidia
# Every investor has one -- the "stock that got away." The one you meant to buy, only to find that it got away from you and has risen 100%, 500%, or even 1,000%. In my case, that stock was Nvidia (NASDAQ: NVDA). I had owned a few shares of the graphics processing units (GPU) pioneer in the early days of my investing journey but ultimately sold them in an unprovoked bid of tax-loss harvesting in early 2010.
# I always meant to buy it back, but the stock price meandered for much of the next five years, and I ultimately lost confidence. Things changed quickly in 2016 when the stock tripled. After that, it just kept getting away from me.
# Fast forward to early 2018. Nvidia still dominated the discrete desktop GPU space, controlling roughly 70% of the market. The company's graphics cards were the processor of choice for cryptocurrency mining, which was booming. Furthermore, there was an ongoing push toward autonomous driving. It was clear that CEO Jensen Huang had a knack for skating to where the puck was going -- recognizing technology trends on the fly and adapting Nvidia's processors and the accompanying software to meet that need.
# After much deliberation, I held my nose and bought Nvidia anyway -- even though the stock had risen 600% over the preceding two years. I have added to my stake several times since. Over the past few years, Nvidia has once again adapted to meet a compelling technology need, becoming the gold standard for generative AI applications.
# Since that initial purchase, Nvidia has soared 768%, and the stock has become my sixth-largest holding, amounting to nearly 6% of my portfolio. The lesson here? It's never too late to buy a quality company, even if the stock has already risen many times over.
# No. 5 and 4: Shopify and Amazon
# Long after Amazon had established itself as the world's largest digital retailer, Shopify (NYSE: SHOP) came on the scene with a different approach to e-commerce. Shopify's founders, having discovered firsthand the difficulties inherent in starting an online sales platform, pivoted the business from selling snowboards to providing customizable templates and other tools that made setting up and running an e-commerce business a snap.
# By solving a common problem among digital retailers, Shopify carved out a profitable niche for itself in a market that was already (and still is) dominated by Amazon. While it isn't an exact apples-to-apples comparison, it helps illustrate an age-old truth in investing that I learned from owning this stock -- there's a Pepsi for every Coke.
# There's another lesson here. I had long been a shareholder of Amazon, but I recognized the value Shopify could bring to the online sales space. Despite the fact that e-commerce was already well represented in my portfolio, I made a sizable investment in Shopify.
# That decision turned out well, as both companies have continued to prosper in the age of digital retail. It also turned out well for me as an investor. Since my first purchase of Shopify shares, the stock is up more than 1,446%, while Amazon has gained 844%. Shopify and Amazon are my fourth and fifth largest holdings heading into 2024, each representing roughly 6% of my portfolio.
# No. 3: Apple
# There's little question that Apple (NASDAQ: AAPL) has become one of the most successful companies in history. Yet, at times over the past few years, some investors concluded the company had reached its zenith. Apple reached a market cap of $1 trillion in 2018, so how much higher could it go?
# There were other worries. As penetration has risen, global smartphone sales have slowed. Since Apple's flagship product -- the iPhone -- historically generates more than half the company's revenue, investor reservations are understandable.
# Despite these challenges, Apple has continued to grow. CEO Tim Cook has succeeded in expanding Apple's services business to become the company's second-biggest breadwinner, behind just the iPhone. The segment brought in $85 billion in fiscal 2023 (ended Sept. 30), making it comparable to a top 50 company in the Fortune 500. Furthermore, the iPhone continues to dominate where it matters, capturing a record 45% of worldwide smartphone revenue and 85% of profits in the second quarter, according to Counterpoint Research.
# Fears that Apple simply couldn't go any higher turned out to be unfounded, an important lesson for investors as its market cap has tripled since 2018. Since my first purchase in 2008, Apple's stock price has surged more than 3,400% to become my third-largest position at 8% of my portfolio. I'm confident there's more to come.
# No. 2: Mercadolibre
# It's likely that many investors have never heard of MercadoLibre (NASDAQ: MELI). The company, which began as a local online auction site, has evolved into the largest e-commerce and payments ecosystem in Latin America, serving 18 countries in the region.
# MercadoLibre not only provides a marketplace for buyers and sellers but also handles shipping and logistics, warehouse and cross-docking, digital payments, consumer and merchant financing, digital wallets, and more. Think of it as the Amazon, Shopify, and PayPal of Latin America all rolled into one.
# Many investors have avoided the stock because of the risks inherent in the region, which is understandable. For example, Argentina -- MercadoLibre's birthplace and one of its biggest markets -- has an inflation rate that clocks in at 143%, and the country just devalued its currency by 50%. Other countries in the region grapple with hyperinflation, economic turmoil, charges of political corruption, poor infrastructure, and more.
# Yet those risks pale in the context of the opportunity. Latin America is years behind the U.S. in terms of e-commerce and digital payment penetration, yet adoption continues to grow. Furthermore, Latin America has twice the population of the U.S. and is the fastest-growing e-commerce market in the world, according to Americas Market Intelligence. Finally, because MercadoLibre takes a cut of each transaction, it has sidestepped many of those risks. As a result, its revenue grew 50% in 2022 while net income soared 480%, a trend that has been ongoing for more than a decade.
# Understanding the risk, viewed through the lens of the significant long-term opportunity, can provide important insight, which gave me the confidence to buy the stock. My rather modest initial investment in MercadoLibre in 2009 has grown by more than 7,300%, and the company now represents 10% of my portfolio. Not bad for a "risky" stock.
# No. 1: Netflix
# Netflix (NASDAQ: NFLX) was the very first stock I bought when I started investing in late 2007. After incurring a late fee at Blockbuster (remember them?) that was more than the cost of buying the movie new, I cut up my membership card and subscribed to Netflix. As an extremely satisfied customer, it made perfect sense to buy the stock once I started investing.
# Back then, the company was a DVD-by-mail service that had recently begun experimenting with streaming video. Netflix had achieved remarkable penetration in its earliest markets, and I surmised the company could expand its success across the country, which was the basis of my investing thesis.
# The company has achieved all that and more, becoming the world's largest subscription streaming video service. The value of the initial shares I bought in 2007 has surged more than 19,000%, making Netflix my largest holding at nearly 11% of my portfolio.
# However, those life-changing gains were only possible because I held the stock for the duration, which is easier said than done. Remember the "Qwikster" fiasco of 2011? All the "Netflix killers" over the years? How about the loss of 1.2 million subscribers early last year?
# There were plenty of excuses to sell Netflix over the years, but for me, the investing thesis never changed, so I held on. And this long-term buy-and-hold strategy continues to win out.
# Should you invest $1,000 in Nvidia right now?
# Before you buy stock in Nvidia, consider this:
# The Motley Fool Stock Advisor analyst team just identified what they believe are the 10 best stocks for investors to buy now... and Nvidia wasn't one of them. The 10 stocks that made the cut could produce monster returns in the coming years.
# Stock Advisor provides investors with an easy-to-follow blueprint for success, including guidance on building a portfolio, regular updates from analysts, and two new stock picks each month. The Stock Advisor service has more than tripled the return of S&P 500 since 2002*.
# See the 10 stocks
# *Stock Advisor returns as of December 11, 2023
# John Mackey, former CEO of Whole Foods Market, an Amazon subsidiary, is a member of The Motley Fool’s board of directors. Danny Vena has positions in Amazon, Apple, MercadoLibre, Netflix, Nvidia, PayPal, and Shopify and has the following options: long January 2024 $95 calls on PayPal. The Motley Fool has positions in and recommends Amazon, Apple, MercadoLibre, Netflix, Nvidia, PayPal, and Shopify. The Motley Fool recommends the following options: long January 2024 $47.50 calls on Coca-Cola and short December 2023 $67.50 puts on PayPal. The Motley Fool has a disclosure policy.
# The views and opinions expressed herein are the views and opinions of the author and do not necessarily reflect those of Nasdaq, Inc.
# (0,
#  {'queries': ['What are the top stocks to invest in for 2024?',
#    'Why is Nvidia stock so popular among investors?',
#    'How has Apple managed to grow despite smartphone market challenges?']})

# %%
async def async_inference(df, num_queries=3):
    loop = asyncio.get_running_loop()

    tasks = [
        loop.run_in_executor(
            None,  
            query_generator.generate_queries,
            df["docno"].iloc[idx],
            df["Article"].iloc[idx],
            num_queries
        )
        for idx in range(len(df))
    ]

    responses = await tqdm_asyncio.gather(*tasks)
    return responses

query_response = await async_inference(document_df, num_queries=3)
query_response
# Out:
# 100%|██████████| 18992/18992 [19:57<00:00, 15.86it/s]
# [(0,
#   {'queries': ['What are the top stocks to invest in for 2024?',
#     'How has Nvidia stock performed over the years?',
#     'What lessons can investors learn from holding Apple and Netflix stocks?']}),
#  (1,
#   {'queries': ['What are the latest analyst recommendations for Apple stock?',
#     "Is Apple's stock a good investment right now?",
#     'How does Zacks Rank compare to average brokerage recommendations for stocks?']}),
#  (2,
#   {'queries': ['Why did Apple shares drop 0.9% recently?',
#     'What caused Prologis shares to fall 1.2%?',
#     "What is the impact of Nippon Steel's acquisition on United States Steel Corporation shares?"]}),
#  (3,
#   {'queries': ["What is NVIDIA's stock price surge in 2023?",
#     "How will generative AI impact NVIDIA's growth in 2024?",
#     'Which companies are in the $1 trillion market cap club alongside NVIDIA?']}),
#  (4,
#   {'queries': ['What are the latest pre-market indicators for NASDAQ 100?',
#     'Which stocks are most active in pre-market trading right now?',
#     'How is NVIDIA performing in pre-market trading today?']}),
#  (5,
#   {'queries': ['What are the top AI stocks to invest in for 2024?',
#     'How is Palantir Technologies performing in 2023?',
#     "What is SoundHound AI's potential market growth?"]}),
#  (6,
#   {'queries': ['What is the latest rating for Apple Inc using the Twin Momentum Investor model?',
#     "How does Dashan Huang's Twin Momentum strategy work for stocks like AAPL?",
#     'What are the top growth stocks in the Communications Equipment industry?']}),
#  (7,
#   {'queries': ['What is the Vanguard S&P 500 ETF (VOO) and how does it perform?',
#     'Best large cap blend ETFs to consider in 2023',
#     'Latest news on Vanguard S&P 500 ETF holdings and expenses']}),
#  (8,
#   {'queries': ['What is the FlexShares Quality Dividend ETF (QDF)?',
#     'How does the FlexShares Quality Dividend ETF compare to other ETFs?',
#     'What are the top holdings in the FlexShares Quality Dividend ETF as of December 2023?']}),
#  (9,
#   {'queries': ['What are the benefits of investing in smart beta ETFs like FlexShares ESG Fund?',
#     'How has the FlexShares STOXX US ESG Select Index Fund performed in 2023?',
#     'What are some alternatives to the FlexShares ESG ETF for large cap investments?']}),
#  (10,
#   {'queries': ['What are the latest updates on U.S. stock index futures for December 19?',
#     "How is the Federal Reserve's policy pivot affecting the S&P 500's performance?",
#     'What caused Apple to pause sales of its smartwatches in the U.S. this week?']}),
#  (11,
#   {'queries': ["What is Warren Buffett's investment strategy for Berkshire Hathaway?",
#     "How have Berkshire Hathaway's AI stock investments performed?",
#     "What percentage of Berkshire Hathaway's portfolio is in Apple, Amazon, and Snowflake?"]}),
#  (12,
#   {'queries': ['What are retained earnings and why are they important?',
#     'Best Warren Buffett stocks to consider for investment in 2023',
#     'How does Bank of America compare to its competitors in retained earnings?']}),
#  (13,
#   {'queries': ['Who will succeed Mark Liu as chairman of TSMC in 2024?',
#     "Latest news on TSMC CEO C.C. Wei's appointment",
#     "What is C.C. Wei's background and experience at TSMC?"]}),
#  (14,
#   {'queries': ['What caused PureCycle Technologies stock to drop 43%?',
#     'Latest news on Adobe and Figma merger termination',
#     'Why is Apple pausing sales of its Series 9 and Ultra 2 smartwatches?']}),
#  (15,
#   {'queries': ['Why is Apple stopping sales of the Apple Watch Series 9 and Ultra 2 in the US?',
#     "What was the ITC ruling on Apple Watch's blood oxygen sensor technology?",
#     'Latest news on the Apple vs. Masimo patent dispute and its impact on Apple products.']}),
#  (16,
#   {'queries': ['What are the latest expectations for Federal Reserve interest rate cuts in 2024?',
#     'How did U.S. stocks perform on December 18, 2023?',
#     "What impact did United States Steel's acquisition by Nippon Steel have on its stock price?"]}),
#  (17,
#   {'queries': ['What is the current NASDAQ 100 after hours indicator?',
#     'Latest stock performance of Apple Inc. AAPL after hours',
#     'Top active stocks in after hours trading including PACB and AMZN']}),
#  (18,
#   {'queries': ['What are the latest expectations for Federal Reserve interest rate cuts in 2024?',
#     'How did U.S. stock markets perform on December 18, 2023?',
#     'What impact did militant attacks in the Red Sea have on crude prices and energy stocks?']}),
#  (19,
#   {'queries': ['What happened to tech stocks on Monday afternoon?',
#     'Why did Adobe and Figma cancel their merger deal?',
#     "What caused Ebix's stock to drop 64% recently?"]}),
#  (20,
#   {'queries': ['What are the top ETFs to invest in for 2024?',
#     'How did QQQ and QQQM perform in 2023?',
#     'Is Alphabet a good investment for 2024?']}),
#  (21,
#   {'queries': ['What are the latest returns for technology hedge funds in 2023?',
#     'How did TMT hedge funds perform compared to the Nasdaq this year?',
#     'Top performing hedge funds in technology for 2023']}),
#  (22,
#   {'queries': ["What are Warren Buffett's biggest unrealized gains in 2023?",
#     "How has Apple's stock performed for Berkshire Hathaway under Warren Buffett?",
#     'Why is American Express a strong investment according to Warren Buffett?']}),
#  (23,
#   {'queries': ['What is the SPDR S&P 500 ETF (SPY) and how does it work?',
#     'Top holdings in the SPDR S&P 500 ETF and their performance in 2023',
#     'Best alternatives to the SPDR S&P 500 ETF for large cap blend exposure']}),
#  (24,
#   {'queries': ['What is the iShares Russell Top 200 Growth ETF (IWY) and how does it perform?',
#     'Best ETFs for large cap growth exposure in 2023',
#     'Latest news on the performance of Apple, Microsoft, and Amazon in IWY ETF']}),
#  (25,
#   {'queries': ['What is the Vanguard Mega Cap ETF (MGC) and how does it perform?',
#     'Top holdings in the Vanguard Mega Cap ETF and their sector exposure',
#     'What are the benefits of investing in large cap blend ETFs like MGC?']}),
#  (26,
#   {'queries': ['What is the Vanguard S&P 500 Growth ETF (VOOG) and its performance in 2023?',
#     'Top holdings in the Vanguard S&P 500 Growth ETF and their impact on returns',
#     'Best large cap growth ETFs to consider alongside VOOG in 2023']}),
#  (27,
#   {'queries': ['What are the best tech stocks to invest in after a market downturn?',
#     'How did Nvidia stock perform in 2023 compared to 2022?',
#     'Why is Apple considered a safe investment during economic challenges?']}),
#  (28,
#   {'queries': ['What did the Fed announce about interest rates on November 1, 2023?',
#     "How did the S&P 500 perform after the Fed's rate decision?",
#     'Are the Magnificent Seven stocks still a good investment in 2024?']}),
#  (29,
#   {'queries': ['Is the iPhone still a growth driver for Apple as of December 2023?',
#     'What are the top growth areas for Apple besides the iPhone?',
#     'Should I invest in Apple stock right now or consider other options?']}),
#  (30,
#   {'queries': ['What are the latest stock market trends as of December 18, 2023?',
#     "How is the Federal Reserve's interest rate decision affecting Wall Street?",
#     'What companies are making headlines in the stock market this week?']}),
#  (31,
#   {'queries': ['What interest rate trends should investors watch for in 2024?',
#     'Why are UPS, Tesla, and Cognex good stocks to consider now?',
#     'How will declining interest rates affect the stock market in 2024?']}),
#  (32,
#   {'queries': ['Why is Apple pausing sales of its Series 9 and Ultra 2 smartwatches?',
#     "Latest news on Apple's smartwatch patent dispute with Masimo",
#     'When will Apple resume sales of the Series 9 and Ultra 2 watches?']}),
#  (33,
#   {'queries': ['What caused the recent rise in U.S. stock indexes on December 18, 2023?',
#     'How did the $14.9 billion buyout deal for U.S. Steel impact its stock price?',
#     'What are the latest expectations for Fed interest rate cuts in early 2024?']}),
#  (34,
#   {'queries': ['What are the latest stock movements for Chevron and Intel?',
#     "How has Chevron's stock performed year to date?",
#     'Which Dow Jones components are currently gaining or losing value?']}),
#  (35,
#   {'queries': ["What is the impact of the EU's Digital Markets Act on US tech companies in 2024?",
#     'Bipartisan lawmakers warn Biden about European tech regulations - what are the key concerns?',
#     "How will the new 'gatekeeper' designation affect companies like Apple and Amazon?"]}),
#  (36,
#   {'queries': ['What are the latest trends for big tech stocks in 2024?',
#     'Can the Magnificent Seven stocks continue to outperform next year?',
#     'What companies could replace the Magnificent Seven in the stock market?']}),
#  (37,
#   {'queries': ["What are the implications of the EU's Digital Markets Act for U.S. tech companies?",
#     'Why are U.S. lawmakers concerned about the EU targeting American firms with new regulations?',
#     "How does the EU's Digital Markets Act affect major tech companies like Apple and Amazon?"]}),
#  (38,
#   {'queries': ['What happened to Goldman Sachs and Apple credit card partnership?',
#     'Latest news on Goldman Sachs consumer banking strategy',
#     'Why is Goldman Sachs looking to exit its credit card deal with Apple?']}),
#  (39,
#   {'queries': ["What are Warren Buffett's top dividend-paying stocks?",
#     "How much has Apple's stock price increased since Berkshire invested?",
#     'Is Bank of America a good long-term investment right now?']}),
#  (40,
#   {'queries': ["What are Warren Buffett's top stocks in 2023?",
#     'Is Apple a good investment for 2024?',
#     'How did American Express perform in Q3 2023?']}),
#  (41,
#   {'queries': ["What are the features of Intel's new Meteor Lake CPUs launched on December 14, 2023?",
#     "How does Intel's Meteor Lake compare to AMD Ryzen in AI performance?",
#     'Is it a good time to invest in Intel stock after the Meteor Lake launch?']}),
#  (42,
#   {'queries': ["What is Nvidia's current market cap in 2023?",
#     "How has Nvidia's stock performance compared to Apple's over the years?",
#     'What are the growth opportunities for Nvidia in the AI chip market?']}),
#  (43,
#   {'queries': ['Best stocks to invest in for 2024',
#     'Latest news on Apple and Amazon stock performance',
#     'Top tech stocks for long-term investment']}),
#  (44,
#   {'queries': ["What factors led to the stock market's surprising gains in 2023?",
#     'Will the Federal Reserve manage a soft landing in 2024?',
#     'Which industries are expected to grow due to macroeconomic trends?']}),
#  (45,
#   {'queries': ['What are the best AI stocks to buy in 2023?',
#     'How is Adobe using AI in its software products?',
#     'Why is Advanced Micro Devices stock rising this year?']}),
#  (46,
#   {'queries': ["Why did Ford's Chief EV Officer buy 182,000 shares on December 8?",
#     'Is Ford stock a good investment option right now?',
#     'What are the latest financial updates for Ford Motor Company after the UAW strikes?']}),
#  (47,
#   {'queries': ['What is the current status of the NASDAQ 100 after hours?',
#     'Latest stock performance for Uber, Lucid, and Pfizer after hours',
#     'Best stocks to buy in the after hours trading session right now']}),
#  (48,
#   {'queries': ['Is PayPal a good stock to buy in 2023?',
#     'What are the risks of investing in PayPal right now?',
#     'How does PayPal compare to competitors like Apple Pay and Stripe?']}),
#  (49,
#   {'queries': ['Why are Chinese agencies banning iPhones in the workplace?',
#     "Latest news on China's push for local tech over foreign devices",
#     "How is Apple's stock reacting to the news about iPhones in China?"]}),
#  (50,
#   {'queries': ['What are the latest dividend increases from Apple and Bank of America in 2023?',
#     "How much of Berkshire Hathaway's portfolio is invested in Apple?",
#     'Is Bank of America a good investment right now?']}),
#  (51,
#   {'queries': ['Is Apple stock a good investment right now?',
#     "What are Warren Buffett's reasons for investing in Apple?",
#     'What are the top stocks to buy instead of Apple?']}),
#  (52,
#   {'queries': ['Best stocks for long-term dividend growth',
#     'Top reasons to invest in Apple, Starbucks, and Costco',
#     "Latest updates on Starbucks' new CEO and strategy"]}),
#  (53,
#   {'queries': ['What happened to Adobe stock after their revenue guidance announcement?',
#     'How did tech stocks perform on October 26, 2023?',
#     "What is the latest news on Apple and Alphabet's app store investigation by the EU?"]}),
#  (54,
#   {'queries': ['What are the latest AI developments from Microsoft and Apple in 2024?',
#     'Is Microsoft stock a good investment right now?',
#     'How is Apple planning to leverage AI technology in the future?']}),
#  (55,
#   {'queries': ['What stocks is Warren Buffett buying in 2024?',
#     'How has Berkshire Hathaway performed under Warren Buffett since the 1960s?',
#     'Why is Apple a key investment for Berkshire Hathaway?']}),
#  (56,
#   {'queries': ['What are the best strong buy stocks to consider for year-end planning?',
#     'Latest analyst ratings for Zscaler, Salesforce, and Vale stocks',
#     'Top strong buy stocks in the cybersecurity and mining sectors for 2023']}),
#  (57,
#   {'queries': ['Latest earnings reports from Apple, Bank of America, and S&P Global',
#     'How did Adobe perform in Q4 2023 earnings season?',
#     'What are the key trends in Q4 earnings estimates for S&P 500 companies?']}),
#  (58,
#   {'queries': ['What are the latest updates on S&P 500 and Nasdaq performance December 14, 2023?',
#     'How did Apple shares react after hitting a record high on December 14, 2023?',
#     'What caused the drop in Adobe shares following their revenue forecast on December 14, 2023?']}),
#  (59,
#   {'queries': ['What caused the S&P 500 to rise on December 14?',
#     'How did Tesla stocks perform recently?',
#     'What are the latest trends in U.S. retail sales for November?']}),
#  (60,
#   {'queries': ['What caused the recent surge in Tesla shares on December 14, 2023?',
#     "How did the Fed's recent decision affect U.S. stock markets?",
#     'What are the latest trends in S&P 500 sector performance?']}),
#  (61,
#   {'queries': ["What is Apple's latest stock performance compared to the S&P 500?",
#     "When is Apple's next earnings report and what are the expected figures?",
#     "How does Apple's PEG ratio compare to the industry average?"]}),
#  (62,
#   {'queries': ['What are the latest trends in mega-cap growth stocks like Apple and Amazon?',
#     'How have the magnificent seven stocks performed in 2024?',
#     'Best ETFs for investing in top tech stocks like Nvidia and Meta Platforms?']}),
#  (63,
#   {'queries': ["What are Tesla's growth prospects for 2024?",
#     'How is Tesla managing its operating margins in 2023?',
#     "What should investors know about Tesla's AI and robotics ventures?"]}),
#  (64,
#   {'queries': ['What are the top performing stocks of 2023 as the Dow hits record highs?',
#     "How did the Fed's recent meeting affect interest rates and the stock market?",
#     'Which stocks are leading the way in the latest Zacks Analyst Blog?']}),
#  (65,
#   {'queries': ['What are the benefits of investing in Ares Capital (ARCC)?',
#     'How does Ares Capital compare to other business development companies?',
#     'Is Ares Capital a good stock to buy for dividend income?']}),
#  (66,
#   {'queries': ["What is Apple's market share in the smartphone industry as of 2023?",
#     "Will Apple's Vision Pro be a game changer for their revenue in 2024?",
#     'What are the risks facing Apple stock in the current market?']}),
#  (67,
#   {'queries': ['Is Apple stock a good buy right now?',
#     "How does Coca-Cola's brand strength impact its stock performance?",
#     'What are the best investment options between Apple and Coca-Cola?']}),
#  (68,
#   {'queries': ["What makes Warren Buffett's investment strategy unique?",
#     'Is Amazon a good stock to buy right now?',
#     'How does Apple compare to Amazon in terms of growth?']}),
#  (69,
#   {'queries': ['What are the Magnificent Seven Stocks and their performance in 2023?',
#     'Which tech ETFs have outperformed the Magnificent Seven ETF this year?',
#     'How are the Magnificent Seven Stocks impacting the Nasdaq index?']}),
#  (70,
#   {'queries': ['What are the benefits of investing in dividend stocks?',
#     'Is Apple a good investment for passive income in 2024?',
#     'Why is Coca-Cola considered a reliable dividend stock?']}),
#  (71,
#   {'queries': ['Latest news on Apple Visa Mastercard antitrust lawsuit',
#     'What are the implications of the Mirage Wine & Spirits lawsuit against Apple?',
#     'How is Apple responding to antitrust claims regarding mobile payments?']}),
#  (72,
#   {'queries': ["Why is Tesla's stock considered undervalued in December 2023?",
#     "Latest news on Tesla's vehicle recall and its impact on stock price",
#     'What are the growth prospects for electric vehicles by 2030?']}),
#  (73,
#   {'queries': ["What stocks are driving the Dow Jones Industrial Average's recent surge?",
#     'How has the Dow Jones performed in bull markets historically?',
#     'Is investing in the SPDR Dow Jones Industrial Average ETF a good strategy?']}),
#  (74,
#   {'queries': ["What are Warren Buffett's top stock picks for the holiday season?",
#     'Is Restaurant Brands stock a good buy right now?',
#     'How has Apple performed in 2023 and what are the growth prospects?']}),
#  (75,
#   {'queries': ['What are the best Dow stocks to invest in as of October 2023?',
#     "How is McDonald's performing compared to the US GDP growth in Q3 2023?",
#     "What is the latest news on Apple's stock and its market cap?"]}),
#  (76,
#   {'queries': ['What are the Magnificent Seven stocks and their impact on the market rally?',
#     'How has the Invesco S&P 500 Equal Weight ETF performed compared to market-cap-weighted indexes?',
#     'Why are tech stocks like Apple and Microsoft dominating the S&P 500 in 2023?']}),
#  (77,
#   {'queries': ['Is Apple stock a good buy at new all-time highs?',
#     "What factors are driving Apple AAPL's stock surge in 2023?",
#     "How has Apple's Services segment contributed to its stock performance?"]}),
#  (78,
#   {'queries': ['Is PayPal a good investment right now?',
#     'What are the latest trends in online payment growth?',
#     'How did PayPal perform during the Thanksgiving-Cyber Monday shopping period?']}),
#  (79,
#   {'queries': ["What is Apple's stock price prediction for 2024?",
#     'How is Apple performing compared to other tech companies in December 2023?',
#     'What are the best ETFs to invest in Apple stock?']}),
#  (80,
#   {'queries': ['What caused the breakup between Apple and Goldman Sachs credit card partnership?',
#     "Top insights on holiday spending trends from Adobe's Vivek Pandya",
#     'How did the stock market perform in November 2023?']}),
#  (81,
#   {'queries': ['Is Apple stock worth the high valuation in December 2023?',
#     "What are the latest updates on Apple's market capitalization and earnings?",
#     'Top reasons to invest in Apple despite recent product revenue declines.']}),
#  (82,
#   {'queries': ['What is the iShares Expanded Tech Sector ETF (IGM) and how does it perform?',
#     'Top holdings in the iShares Expanded Tech Sector ETF (IGM) 2023',
#     'Best ETFs for technology sector exposure in 2023']}),
#  (83,
#   {'queries': ["What is the latest on Apple's stock performance?",
#     'How are earnings estimates changing for Apple Inc. in 2023?',
#     'Is Apple stock currently overvalued compared to its peers?']}),
#  (84,
#   {'queries': ['What is a long straddle options strategy?',
#     'Best long straddle trades for December 12th 2023',
#     'How to mitigate risk with long straddles in options trading?']}),
#  (85,
#   {'queries': ['What are the latest after hours trading results for NASDAQ 100?',
#     'Top active stocks in after hours trading right now',
#     'How is Rivian Automotive performing in after hours trading?']}),
#  (86,
#   {'queries': ["What is Apple's new offer regarding mobile payments in the EU?",
#     "How could Apple's NFC technology access impact EU antitrust charges?",
#     "Latest news on Apple's antitrust issues with Spotify and other services in Europe."]}),
#  (87,
#   {'queries': ['What are penny stocks and why are they risky?',
#     'Is Opko Health (OPK) a good investment right now?',
#     'What is the target price for Opko Health stock in 2023?']}),
#  (88,
#   {'queries': ['What makes Warren Buffett such a successful investor?',
#     'How did Berkshire Hathaway grow to be worth $772 billion?',
#     'Could Berkshire Hathaway reach a $1 trillion valuation in 2024?']}),
#  (89,
#   {'queries': ["What drove Roku's stock price up by 149% in 2023?",
#     'Is Roku stock a good investment right now?',
#     'How is Roku managing its costs to achieve profitability?']}),
#  (90,
#   {'queries': ['Foxconn investment plans in Karnataka December 2023',
#     'How many jobs will Foxconn create in India?',
#     "Latest news on Foxconn's iPhone manufacturing in Karnataka"]}),
#  (91,
#   {'queries': ['What are the latest inflows for the WisdomTree U.S. Quality Dividend Growth Fund?',
#     'How did Microsoft and Apple perform in the DGRW ETF recently?',
#     'Which ETF had the biggest percentage increase in inflows this week?']}),
#  (92,
#   {'queries': ["How did Apple stock perform after Foxconn's investment announcement in India on Wednesday?",
#     "What are the latest updates on Meta Platforms' use of pirated books for AI training?",
#     'Which companies are being added and removed from the Nasdaq-100 Index for this month?']}),
#  (93,
#   {'queries': ['What are the new regulations under the Digital Services Act for Apple and Google?',
#     'How is the EU enforcing the Digital Services Act on major tech companies?',
#     'What risks are associated with the App Store and Google Play according to the European Commission?']}),
#  (94,
#   {'queries': ['What are the top performing technology ETFs in 2023?',
#     'How did the AI boom impact the stock market this year?',
#     "Latest updates on the Fed's interest rate cuts and their effect on tech stocks."]}),
#  (95,
#   {'queries': ["What caused Jabil's shares to rise 5.3% on December 14?",
#     'How is Jabil adjusting to weak demand in the electronics market?',
#     "What are Jabil's forecasts for revenue growth in clean energy and AI sectors?"]}),
#  (96,
#   {'queries': ['What are the best beaten-down stocks to watch for a rebound in 2024?',
#     'How is Dollar General adjusting its strategy after falling sales?',
#     "Why is Alibaba's stock down this year despite its profitability?"]}),
#  (97,
#   {'queries': ["What is Intel's new Meteor Lake chip and how does it work?",
#     "Best laptops featuring Intel's latest chip released on December 14",
#     'How is Intel competing with Nvidia in the AI data center market?']}),
#  (98,
#   {'queries': ['What are the top Warren Buffett stocks to invest in right now?',
#     'How is Coca-Cola performing in Q3 2023?',
#     "Why are analysts bullish on Amazon's stock this year?"]}),
#  (99,
#   {'queries': ['What are the top stocks driving the Dow Jones to new highs in December 2023?',
#     "How will the Fed's potential rate cuts impact the stock market next year?",
#     'What are the best-performing stocks in the Dow Jones this year?']}),
#  (100,
#   {'queries': ['What is the future outlook for Apple stock in 2028?',
#     "How is Apple's services revenue growing compared to iPhone sales?",
#     "What are the latest projections for Apple's revenue growth by 2028?"]}),
#  (101,
#   {'queries': ['What are the latest expectations for Fed rate cuts in 2024?',
#     "How did Apple's stock perform on December 14, 2023?",
#     'What factors contributed to the rise of Wall Street indexes recently?']}),
#  (102,
#   {'queries': ['Is Apple stock too high to buy right now?',
#     'What are the latest earnings estimates for Apple AAPL?',
#     "How has Apple's stock performed in 2023?"]}),
#  (103,
#   {'queries': ['What are the latest challenges facing Disney stock in 2023?',
#     'How is Bob Iger addressing the activist investor pressure on Disney?',
#     'What are the potential strategies for Disney to improve its stock value?']}),
#  (104,
#   {'queries': ["What is Berkshire Hathaway's recent investment in Occidental Petroleum?",
#     'How much of Occidental Petroleum does Berkshire Hathaway own now?',
#     "What are the details of Berkshire Hathaway's warrants for Occidental shares?"]}),
#  (105,
#   {'queries': ['What are the best stocks to invest in for growth right now?',
#     'Is Alphabet a good investment after its recent AI advancements?',
#     'How is Carnival recovering from the pandemic and what are its current stock prices?']}),
#  (106,
#   {'queries': ["What is Apple's stock price as of December 13, 2023?",
#     "How did the Federal Reserve's announcement affect U.S. stocks on December 13?",
#     'What are the latest stock performance trends for Apple in 2023?']}),
#  (107,
#   {'queries': ["What are Warren Buffett's latest investment moves in Berkshire Hathaway as of December 2023?",
#     'Is it a good time to invest in Berkshire Hathaway stocks right now?',
#     "What are the top stocks in Berkshire Hathaway's portfolio as of December 12, 2023?"]}),
#  (108,
#   {'queries': ["What does the Fed's dovish shift mean for U.S. stocks in December 2023?",
#     "How are Treasury yields impacting the S&P 500 after the Fed's latest announcement?",
#     'What are the projections for interest rates and corporate earnings in 2024?']}),
#  (109,
#   {'queries': ['Epic Games wins antitrust trial against Google Play on December 11',
#     "What are the implications of Epic Games' victory over Google Play?",
#     'Latest updates on Epic Games lawsuit against Google and its impact on app developers']}),
#  (110,
#   {'queries': ["What are the new features in Google's NotebookLM app?",
#     'How is Google competing with Microsoft and Apple in note-taking apps?',
#     "What impact will generative AI have on Alphabet's revenue growth?"]}),
#  (111,
#   {'queries': ['What are the latest price targets for the S&P 500 in 2024?',
#     'Is Alphabet a good stock to buy right now?',
#     'How is Paycom Software performing in the payroll software market?']}),
#  (112,
#   {'queries': ['What are the benefits of investing in S&P 500 ETFs?',
#     'Is Vanguard S&P 500 ETF a good investment for 2023?',
#     "How did Warren Buffett's investment in S&P 500 ETFs perform over the years?"]}),
#  (113,
#   {'queries': ['What is the SPDR Portfolio S&P 500 ETF (SPLG) and how does it perform?',
#     'Top holdings in the SPDR Portfolio S&P 500 ETF explained',
#     'Why should I invest in large cap blend ETFs like SPLG?']}),
#  (114,
#   {'queries': ['What is the iShares S&P 100 ETF and how does it perform?',
#     'Top holdings in the iShares S&P 100 ETF (OEF) as of December 2023',
#     'Best large cap blend ETFs to consider for investment']}),
#  (115,
#   {'queries': ['What new regulations is the RBA considering for mobile wallets in Australia?',
#     'How will the Reserve Bank of Australia support the transition to the New Payments Platform (NPP)?',
#     'Are retailers allowed to charge surcharges on buy-now-pay-later services in Australia?']}),
#  (116,
#   {'queries': ['What are the top stocks to buy before year-end 2023?',
#     'How did the Magnificent 7 stocks influence the S&P 500 this year?',
#     'Is CrowdStrike a good investment for 2023?']}),
#  (117,
#   {'queries': ['Is it too late to invest in Apple stock after its recent gains?',
#     "What are Warren Buffett's top stock picks for 2023?",
#     "How is Apple's services business contributing to its growth?"]}),
#  (118,
#   {'queries': ['What is the latest options trading volume for Par Technology Corp (PAR)?',
#     'Top options for Apple Inc (AAPL) with high trading volume this month',
#     'How is Sabre Corp (SABR) performing in options trading compared to last month?']}),
#  (119,
#   {'queries': ['Is Apple stock overvalued in 2024?',
#     'What are the latest iPhone sales figures for fiscal 2023?',
#     'Top investment alternatives to Apple stock right now?']}),
#  (120,
#   {'queries': ['What is the John Hancock Multifactor Large Cap ETF (JHML) and its performance?',
#     'How do smart beta ETFs differ from traditional ETFs?',
#     'What are the top holdings in the John Hancock Multifactor Large Cap ETF?']}),
#  (121,
#   {'queries': ["What to expect from the Federal Reserve's interest rate decision on December 13, 2023?",
#     'Latest updates on S&P 500 and Nasdaq performance this week',
#     "Why did Cigna's stock jump after ending its acquisition talks with Humana?"]}),
#  (122,
#   {'queries': ['What caused the big outflow in iShares MSCI USA Quality Factor ETF?',
#     'Latest updates on GPIX ETF unit declines',
#     'How are Visa and Apple performing in the market this week?']}),
#  (123,
#   {'queries': ['What is the date for the Nadal vs Alcaraz tennis match on Netflix?',
#     "Latest news on Netflix's live sports streaming plans",
#     'How is Netflix competing with Amazon and Apple in live sports?']}),
#  (124,
#   {'queries': ['What rate cuts can we expect in 2024?',
#     'How should investors prepare for a slowing economy in 2024?',
#     'What are the latest trends in ETF inflows and investments?']}),
#  (125,
#   {'queries': ['What new regulations is the Reserve Bank of Australia considering for mobile wallets as of December 2023?',
#     "How will the RBA's plans for payments system modernization affect retailers and BNPL services?",
#     "Latest updates on the RBA's central bank digital currency project and its impact on Australia's payment systems."]}),
#  (126,
#   {'queries': ['What are the latest after hours trading updates for NASDAQ 100?',
#     'Which stocks are most active in after hours trading right now?',
#     'How did Oracle and Intel perform after hours on NASDAQ?']}),
#  (127,
#   {'queries': ['How does the latest Google Wallet update for Wear OS enhance user experience?',
#     'What are the growth projections for the global smartwatch market by 2030?',
#     'How is Alphabet competing with Apple and Microsoft in the digital wallet space?']}),
#  (128,
#   {'queries': ['What to expect from Apple stock in 2024?',
#     'Is Apple stock overvalued after its 2023 rally?',
#     'How is Apple shifting its operations away from China?']}),
#  (129,
#   {'queries': ['What are the top tech stocks to buy in 2024?',
#     'How is Alphabet performing in the digital ad market?',
#     'Is Apple a good investment despite recent sales declines?']}),
#  (130,
#   {'queries': ['What are the latest ETF inflows for iShares iBoxx $ High Yield Corporate Bond ETF?',
#     'Which ETF had the biggest percentage increase in inflows recently?',
#     'How are Apple and Microsoft performing in the WisdomTree U.S. Quality Growth Fund?']}),
#  (131,
#   {'queries': ['What are the Magnificent Seven tech stocks in 2023?',
#     'Is Nvidia stock still a good investment after its recent gains?',
#     'How is the AI chip market expected to grow by 2030?']}),
#  (132,
#   {'queries': ["What caused Lumentum's stock to drop nearly 50% in the last three years?",
#     'Is Lumentum a good investment for 2024?',
#     "How did Lumentum's revenue growth change over the past five years?"]}),
#  (133,
#   {'queries': ['What makes the WisdomTree US Quality Dividend Growth Fund (DGRW) a good investment?',
#     'How has DGRW performed compared to the S&P 500 and other dividend ETFs in 2023?',
#     'Why should investors consider dividend ETFs that focus on return on assets and equity?']}),
#  (134,
#   {'queries': ['What are the benefits of investing in the S&P 500 index fund?',
#     'How much would $1,000 invested in Apple stock be worth now?',
#     'What are the top stocks to invest in for high returns in 2024?']}),
#  (135,
#   {'queries': ["What does Google's defeat against Epic Games mean for app stores?",
#     "How will the jury ruling affect Google's Play Store fees and policies?",
#     'Latest updates on Epic Games vs Google legal battle December 2023']}),
#  (136,
#   {'queries': ["What is Goldman Sachs' strategy for the private credit market in 2023?",
#     'How are major banks like Citigroup and JPMorgan expanding into private lending?',
#     'What recent changes did Goldman Sachs make in its executive team for private credit?']}),
#  (137,
#   {'queries': ["What are the latest updates on Apple's App Store rules in December 2023?",
#     "How could the EU's potential fine impact Apple's business?",
#     "Why did Spotify complain about Apple's App Store practices?"]}),
#  (138,
#   {'queries': ["What are Warren Buffett's top dividend stocks for 2023?",
#     'How much dividend income does Berkshire Hathaway expect from Bank of America?',
#     'Why is Coca-Cola considered a strong investment for dividend income?']}),
#  (139,
#   {'queries': ["What is Murata Manufacturing's strategy for selling to Chinese smartphone makers in emerging markets?",
#     'How is the smartphone market expected to grow in 2025 according to Murata?',
#     'Latest smartphone sales trends in China and emerging markets for 2023']}),
#  (140,
#   {'queries': ['What are the latest after hours stock movements for the NASDAQ 100?',
#     'How is Apple Inc. performing in after hours trading?',
#     'What is the current recommendation for Microsoft Corporation stock?']}),
#  (141,
#   {'queries': ['Latest news on Apple allowing competitors access to mobile payment systems',
#     'Why did Oracle shares drop 12% after fiscal Q2 results?',
#     "What happened with Alphabet's antitrust trial against Epic Games?"]}),
#  (142,
#   {'queries': ["What is Apple's new policy on push notification data for law enforcement as of December 2023?",
#     "How does Apple's push notification data policy compare to Google's?",
#     "Why is Senator Ron Wyden supporting Apple's changes to data requests for push notifications?"]}),
#  (143,
#   {'queries': ['Can Shiba Inu cryptocurrency reach $0.01 in the future?',
#     "Why hasn't Shiba Inu performed well in 2023 compared to other cryptocurrencies?",
#     'What are the top stocks to invest in instead of Shiba Inu?']}),
#  (144,
#   {'queries': ["What happened to Alex Jones' Twitter account on Dec 10, 2023?",
#     "Latest updates on Elon Musk's poll about reinstating Alex Jones on X",
#     "Why did advertisers pause their ads on X after Musk's comments?"]}),
#  (145,
#   {'queries': ['Is Apple stock worth buying in December 2023?',
#     "What are the latest updates on Apple's market cap and growth potential?",
#     "How has Apple's buyback program impacted its earnings per share?"]}),
#  (146,
#   {'queries': ["When will the next bull market start after last year's bear market?",
#     'What are the top stocks to buy for a potential bull market in 2024?',
#     'How did Shopify perform during Black Friday-Cyber Monday sales this year?']}),
#  (147,
#   {'queries': ['Will the stock market rise in 2024?',
#     'Impact of shrinking money supply on stocks',
#     'What are the best stocks to buy now instead of Walmart?']}),
#  (148,
#   {'queries': ["What are Warren Buffett's top AI investments in 2023?",
#     "How much of Berkshire Hathaway's portfolio is in Apple stock?",
#     'Why is Snowflake considered a valuable AI stock right now?']}),
#  (149,
#   {'queries': ['Who is the new CEO of Our Next Energy as of December 10, 2023?',
#     'What led to the layoffs at Our Next Energy last month?',
#     "Latest updates on Our Next Energy's gigafactory plans in Michigan."]}),
#  (150,
#   {'queries': ['What are the latest AI investments by Meta Platforms?',
#     'How is Apple using AI in its products?',
#     "What is the significance of Meta's Llama 2 AI model release?"]}),
#  (151,
#   {'queries': ['What are the best growth stocks to invest in for 2024?',
#     "How did AST SpaceMobile's recent satellite call impact its stock?",
#     'Is Apple stock a good buy right now given its market position?']}),
#  (152,
#   {'queries': ['What are the best foreign stocks to buy in the U.S. right now?',
#     "How has Spotify's growth impacted its stock value in 2023?",
#     'Why is Taiwan Semiconductor considered a crucial player in the semiconductor industry?']}),
#  (153,
#   {'queries': ['Why is Taiwan Semiconductor important for AI investment?',
#     'What are the best stocks to invest in for AI growth in December 2023?',
#     'Should I buy Taiwan Semiconductor Manufacturing stock after the latest Motley Fool recommendations?']}),
#  (154,
#   {'queries': ['What are the best stocks to buy for the new year?',
#     'Top long-term investment stocks to consider in 2024',
#     'Latest insights on Amazon, Coca-Cola, and Apple stocks']}),
#  (155,
#   {'queries': ['Best tech stocks to buy in 2024',
#     'Why is Shopify a good investment right now?',
#     'Latest performance of Apple stock and its services revenue']}),
#  (156,
#   {'queries': ["What impact did cyclone Michaung have on Chennai's manufacturing plants in December 2023?",
#     'How much financial aid is Tamil Nadu receiving for cyclone recovery efforts?',
#     'What infrastructure issues are being raised in Chennai after the recent floods?']}),
#  (157,
#   {'queries': ['What is Apple planning for iPad production in Vietnam?',
#     "Latest news on Apple's iPad development resources and BYD partnership",
#     'Why are Apple suppliers investing in Vietnam for production diversification?']}),
#  (158,
#   {'queries': ["What are the latest plans for Tata Group's new iPhone assembly plant in India?",
#     'How is Apple expanding its manufacturing in India beyond China?',
#     "What impact will Tata's new iPhone factory have on local employment in Tamil Nadu?"]}),
#  (159,
#   {'queries': ["What are Warren Buffett's top stock holdings as of December 2023?",
#     "How has Apple become Berkshire Hathaway's largest investment?",
#     "Why is Bank of America a key part of Berkshire Hathaway's portfolio?"]}),
#  (160,
#   {'queries': ['Is Apple or Shopify a better investment right now?',
#     'What is the cash flow yield for Apple and Shopify stocks?',
#     'How have Apple and Shopify performed over the last five years?']}),
#  (161,
#   {'queries': ["What are Warren Buffett's top stock picks for long-term investment?",
#     "How has Berkshire Hathaway's investment in Apple performed over the years?",
#     'Why is Coca-Cola considered a great dividend stock by Warren Buffett?']}),
#  (162,
#   {'queries': ['Latest news on Apple executive departures December 2023',
#     'Who is taking over design at Apple after Tang Tan leaves?',
#     'Impact of Apple iPhone design changes with new leadership in 2023']}),
#  (163,
#   {'queries': ['What are the returns of the Magnificent Seven stocks in 2023?',
#     'Is Nvidia the best stock to buy for AI growth?',
#     'Why is Alphabet considered a top stock for 2024 and 2025?']}),
#  (164,
#   {'queries': ["What is Apple's stock price change on the latest trading day?",
#     'How did Apple perform compared to the S&P 500 in the last month?',
#     'What are the earnings estimates for Apple in the upcoming financial results?']}),
#  (165,
#   {'queries': ['Should I invest in AMD stock now?',
#     'What are the latest updates on Advanced Micro Devices and AI?',
#     'What are the top stocks recommended by The Motley Fool for December 2023?']}),
#  (166,
#   {'queries': ['What are the latest earnings results for 3D Systems (DDD)?',
#     'How has 3D Systems stock performed since its last earnings report?',
#     'What is the outlook for 3D Systems leading up to its next earnings release?']}),
#  (167,
#   {'queries': ['Why did Apple stock reach a $3 trillion market cap in December 2023?',
#     'Is Apple stock still a good investment after its recent surge?',
#     'What are the top stocks to buy instead of Apple right now?']}),
#  (168,
#   {'queries': ['What are the latest trends in the mini-computer industry as of December 2023?',
#     'How are Apple, HP, and 3D Systems performing in the current market?',
#     'What factors are affecting the demand for personal computers and smartphones in 2023?']}),
#  (169,
#   {'queries': ['How much money will Warren Buffett make in 2023?',
#     "What caused Berkshire Hathaway's stock to rise in 2023?",
#     'Best stocks to invest in besides Berkshire Hathaway right now.']}),
#  (170,
#   {'queries': ['What is the latest outlook for Apple stock in 2023?',
#     'How is Apple appealing to Gen Z consumers?',
#     "What are the key factors driving Apple's services revenue growth?"]}),
#  (171,
#   {'queries': ['What are the latest trends in the Nasdaq index as of December 7, 2023?',
#     'How did Alphabet and other tech stocks perform on December 7, 2023?',
#     'What impact might the upcoming jobs report have on Federal Reserve interest rate decisions?']}),
#  (172,
#   {'queries': ["What are Berkshire Hathaway's biggest investments in 2023?",
#     "How much of Berkshire Hathaway's portfolio is in Apple stock?",
#     'Why is Warren Buffett investing in U.S. Treasury bills now?']}),
#  (173,
#   {'queries': ['What are the latest stock performance trends for Nvidia and PayPal in 2023?',
#     'Is Nvidia a good investment for long-term growth in AI technology?',
#     'How is PayPal recovering after a significant drop in its stock price?']}),
#  (174,
#   {'queries': ['Is Apple or Amazon a better stock to buy in December 2023?',
#     'What are the latest financial metrics for Apple and Amazon?',
#     "Why is Apple's stock considered more valuable than Amazon's right now?"]}),
#  (175,
#   {'queries': ["What are Apple's stock performance details in 2023?",
#     'How is Merck performing in the Dow Jones this week?',
#     'Latest updates on Johnson & Johnson and Caterpillar stock movements']}),
#  (176,
#   {'queries': ["Who is leading Tesla's Dojo supercomputer project now?",
#     "What impact could Tesla's Dojo supercomputer have on its market value?",
#     "Latest news on Tesla's Dojo supercomputer and its AI training capabilities"]}),
#  (177,
#   {'queries': ['What caused the Nasdaq surge on December 7, 2023?',
#     "Latest news on Alphabet's new AI model and its impact on stocks",
#     'How are interest rate cuts affecting the S&P 500 and tech stocks?']}),
#  (178,
#   {'queries': ["What was the sentence for Apple's former lawyer Gene Levoff on insider trading charges?",
#     "Latest news on Gene Levoff's insider trading case and sentencing details",
#     'How did Gene Levoff exploit his role at Apple for insider trading?']}),
#  (179,
#   {'queries': ['What are the best Nasdaq stocks to buy in December 2023?',
#     'How is Apple performing in the stock market right now?',
#     'Why is Coinbase stock rising with the current cryptocurrency rally?']}),
#  (180,
#   {'queries': ['What are the best dividend-paying stocks for 2024?',
#     'How did Restaurant Brands perform in the latest quarter?',
#     'Why is Apple stock considered a good long-term investment?']}),
#  (181,
#   {'queries': ['Latest data breach statistics in the U.S. for 2023',
#     'How is end-to-end encryption changing data security?',
#     'What did the Apple-backed study reveal about data breaches and technology vendors?']}),
#  (182,
#   {'queries': ["What are the latest updates on Alphabet's AI model as of December 7, 2023?",
#     'How did Advanced Micro Devices stock perform after the AI-chip market forecast?',
#     'What impact did jobless claims have on the stock market on December 7, 2023?']}),
#  (183,
#   {'queries': ['What is the Goldman Sachs ActiveBeta World Low Vol Plus Equity ETF (GLOV)?',
#     'Best smart beta ETFs for 2023',
#     'Top holdings in Goldman Sachs ActiveBeta World Low Vol Plus Equity ETF']}),
#  (184,
#   {'queries': ['Is Apple stock a good investment right now?',
#     "What are Warren Buffett's top stock picks in 2023?",
#     "How has Apple's services revenue performed recently?"]}),
#  (185,
#   {'queries': ['What is the iShares Core S&P U.S. Growth ETF (IUSG) and its performance?',
#     'How do smart beta ETFs work compared to traditional ETFs?',
#     'What are the top holdings in the iShares Core S&P U.S. Growth ETF as of December 2023?']}),
#  (186,
#   {'queries': ['What are the latest trends in cryptocurrency revenue growth?',
#     'Which AI stocks are outperforming Bitcoin and Ethereum right now?',
#     "How is Alphabet's AI strategy impacting its stock value in 2023?"]}),
#  (187,
#   {'queries': ['Who is the most accurate analyst for Apple stock?',
#     "What are Krish Sankar's top stock recommendations?",
#     'How to find the best Wall Street analysts to follow?']}),
#  (188,
#   {'queries': ['Apple iPhone 16 battery sourcing news December 2023',
#     'Best Indian factories for Apple iPhone components',
#     "Latest updates on Apple's supply chain for iPhone 16"]}),
#  (189,
#   {'queries': ["What is Nio's plan for its battery manufacturing unit as of December 2023?",
#     'How is Nio trying to improve profitability amid growing losses in the EV market?',
#     "Latest news on Nio's battery spin-off and its impact on the company's future strategy."]}),
#  (190,
#   {'queries': ["What caused Apple's stock to rise in November 2023?",
#     'Is now a good time to buy or sell AAPL stock?',
#     "How are iPhone 15 sales affecting Apple's stock performance?"]}),
#  (191,
#   {'queries': ['What caused the NRF to retract its claim about organized retail crime on December 5, 2023?',
#     'How much do retailers lose to organized retail crime according to recent reports?',
#     'What are the impacts of organized retail crime on major retailers like Target and Walgreens?']}),
#  (192,
#   {'queries': ['What is the current market cap of Apple stock as of December 5, 2023?',
#     'Is Apple stock a good long-term investment based on recent analyst ratings?',
#     "What factors are driving the growth of Apple's iPhone and Services revenue?"]}),
#  (193,
#   {'queries': ['How did the stock market perform on November 1, 2023?',
#     'What were the job openings in the JOLTS report for October 2023?',
#     'Which stocks are recommended by Zacks Investment Research right now?']}),
#  (194,
#   {'queries': ['What did Senator Ron Wyden say about smartphone surveillance on December 6?',
#     'How are Apple and Google involved in government push notification monitoring?',
#     'Latest news on privacy concerns with app push notifications and government data requests.']}),
#  (195,
#   {'queries': ["What is Roku's new collaboration with Tennis Channel about?",
#     'How will T2 enhance the Roku Channel experience for sports fans?',
#     'What are the latest features Roku added to boost streaming hours?']}),
#  (196,
#   {'queries': ['What are the best ETFs to invest in Apple stock right now?',
#     'How did Apple regain its $3 trillion market cap in October 2023?',
#     "What are analysts' price targets for Apple stock this month?"]}),
#  (197,
#   {'queries': ['What are the latest trends in the mini computer industry?',
#     'How is Apple performing in the smartphone market in 2023?',
#     'What challenges are facing the personal computer industry?']}),
#  (198,
#   {'queries': ['What are the best tech-focused ETFs to invest in right now?',
#     'How does Invesco QQQ Trust compare to Vanguard Information Technology Index Fund?',
#     'What are the top performing stocks in the tech sector over the past decade?']}),
#  (199,
#   {'queries': ['What are the best niche tech stocks to invest in right now?',
#     'How did Sotera Health Company perform in Q3 2023?',
#     'What makes Constellation Software a unique investment opportunity?']}),
#  (200,
#   {'queries': ['What are the top AI stocks to invest in right now?',
#     'How is Lemonade using AI to change the insurance industry?',
#     'Why is UiPath considered a top AI stock by Cathie Wood?']}),
#  (201,
#   {'queries': ['What are the latest after hours stock prices for NASDAQ 100?',
#     "How did Chewy's stock perform after their Q3 earnings report?",
#     'Which stocks are currently recommended to buy in the after hours market?']}),
#  (202,
#   {'queries': ['What are the latest stock performances of Apple and PayPal in the Nasdaq 100?',
#     "How has Apple's stock performed year to date compared to PayPal?",
#     'Which companies are the top movers in the Nasdaq 100 right now?']}),
#  (203,
#   {'queries': ["What are Apple's production concerns regarding India's universal charging port rule?",
#     "How will the EU's charging port regulations affect iPhone sales in India?",
#     "Latest updates on Apple's lobbying efforts for exemptions in India regarding charging ports"]}),
#  (204,
#   {'queries': ['Will Microsoft surpass Apple as the largest company in 2024?',
# ...
#  (932,
#   {'queries': ['Dell Technologies Q3 2024 earnings report highlights',
#     "What caused Dell's stock to drop after earnings announcement?",
#     "Latest updates on Dell's revenue and market performance for fiscal 2024"]}),
#  (933,
#   {'queries': ['What is the latest options trading volume for Adobe Inc (ADBE)?',
#     'Top options for Lithia Motors Inc (LAD) expiring in June 2024',
#     'Latest trading activity for Couchbase Inc (BASE) options']}),
#  (934,
#   {'queries': ["What were Domo's earnings for Q3 fiscal 2024?",
#     "How did Domo's revenue compare to last year?",
#     "What is Domo's stock performance year to date?"]}),
#  (935,
#   {'queries': ["What are the benefits of Bell Canada's new 5G+ spectrum licenses?",
#     'How much did Bell Canada spend on the 3800 MHz spectrum auction?',
#     "What are BCE Inc.'s latest earnings and revenue growth projections for 2023?"]}),
#  (936,
#   {'queries': ['What are the expected earnings for SentinelOne on December 5, 2024?',
#     "How has SentinelOne's customer base grown recently?",
#     "What are the latest developments in SentinelOne's cybersecurity solutions?"]}),
#  (937,
#   {'queries': ['What are the growth opportunities for Flex Ltd. in 2024?',
#     'How did Flex Ltd. perform compared to its sub-industry this year?',
#     'What are the latest earnings estimates for Flex Ltd. and its impact on investors?']}),
#  (938,
#   {'queries': ['What are the latest inflows for the Invesco NASDAQ 100 ETF (QQQM)?',
#     'How did Broadcom, Tesla, and Adobe perform recently in the QQQM ETF?',
#     'What is the 52-week range and price performance of QQQM compared to its moving average?']}),
#  (939,
#   {'queries': ['How has Adobe Systems (ADBE) performed in 2023?',
#     'What are the top-performing Computer and Technology stocks this year?',
#     'Why is Crexendo (CXDO) a good investment right now?']}),
#  (940,
#   {'queries': ["What is driving Axcelis Technologies' stock growth in 2023?",
#     'Latest earnings report for Axcelis Technologies ACLS Q3 2023',
#     "How is the demand for silicon carbide impacting Axcelis' revenue?"]}),
#  (941,
#   {'queries': ['NetApp Q2 fiscal 2024 earnings report',
#     "What are NetApp's revenue projections for fiscal 2024?",
#     'Latest updates on NetApp stock performance after earnings announcement']}),
#  (942,
#   {'queries': ['Is C3.ai a good investment in 2023?',
#     'How is Adobe integrating AI into its software?',
#     'What are the risks of investing in C3.ai versus Adobe?']}),
#  (943,
#   {'queries': ["What are the latest updates on Adobe's acquisition of Figma?",
#     "How will Adobe's $20 billion deal affect competition in the design software market?",
#     "What are the EU's antitrust concerns regarding Adobe and Figma's merger on December 8?"]}),
#  (944,
#   {'queries': ['Latest performance of technology stocks in 2023',
#     'Adobe vs Salesforce stock analysis and price targets',
#     'Best tech stocks to invest in right now']}),
#  (945,
#   {'queries': ["What are Bank of America's predictions for the S&P 500 in 2024?",
#     'How did Amazon perform during Black Friday 2023?',
#     'Is Uber Technologies expected to surprise investors in 2024?']}),
#  (946,
#   {'queries': ['What caused the drop in tech stocks on October 3rd?',
#     'How did Salesforce perform in its latest earnings report?',
#     "What are the implications of Adobe's acquisition of Figma?"]}),
#  (947,
#   {'queries': ['What were the Cyber Monday sales figures for 2023?',
#     'Best deals on electronics during Cyber Monday 2023',
#     'How is Buy Now, Pay Later impacting holiday shopping this year?']}),
#  (948,
#   {'queries': ['What were the Cyber Monday sales figures for 2023?',
#     'Top discounts on beauty products and electronics for Christmas shopping',
#     'How much did online shopping increase on Cyber Monday compared to last year?']}),
#  (949,
#   {'queries': ["What are the implications of Adobe's $20 billion acquisition of Figma for the UK digital design sector?",
#     "How will the CMA's investigation affect Adobe and Figma's merger plans?",
#     'What is the current market share of Figma in the UK product design software industry?']}),
#  (950,
#   {'queries': ["What are the implications of Adobe's $20 billion acquisition of Figma in November 2023?",
#     "How will the CMA's probe affect Adobe's deal with Figma?",
#     "Latest updates on Adobe's acquisition of Figma and competition concerns in the UK digital design market."]}),
#  (951,
#   {'queries': ['What is the Zacks Focus List and how does it work?',
#     'Top stocks to invest in according to Zacks Premium',
#     'Latest performance of Adobe Inc. (ADBE) stock and earnings estimates']}),
#  (952,
#   {'queries': ['What is the SPDR NYSE Technology ETF (XNTK) and how does it perform?',
#     'Top holdings in the SPDR NYSE Technology ETF (XNTK) as of November 2023',
#     'Best technology ETFs to invest in besides XNTK right now']}),
#  (953,
#   {'queries': ["What is driving SAP's share price increase in 2023?",
#     "How is SAP's Rise with SAP solution impacting cloud revenues?",
#     'What are the latest earnings estimates for SAP SE?']}),
#  (954,
#   {'queries': ['What are the best AI stocks to invest in besides Nvidia?',
#     'How is AMD competing with Nvidia in the AI chip market?',
#     "Latest updates on Adobe's AI tools and their impact on growth."]}),
#  (955,
#   {'queries': ["What is Adobe's stock performance ahead of its earnings report on December 13, 2023?",
#     "How has Adobe Systems' stock price changed in the past month?",
#     "What are the latest analyst estimates for Adobe's earnings and revenue?"]}),
#  (956,
#   {'queries': ['How much are Americans expected to spend on Cyber Monday 2023?',
#     'What are the top deals on Cyber Monday this year?',
#     'Are retailers worried about profit margins during the holiday season?']}),
#  (957,
#   {'queries': ['How much are shoppers expected to spend on Cyber Monday 2023?',
#     'What discounts can consumers expect from retailers like Amazon and Walmart this Cyber Monday?',
#     'Which retailers are predicted to be the biggest winners this holiday season?']}),
#  (958,
#   {'queries': ['How did Shopify perform on Black Friday 2023?',
#     'What were the Black Friday sales figures for Shopify merchants?',
#     'Is Shopify a good stock to buy right now after its recent growth?']}),
#  (959,
#   {'queries': ["What are the latest features of Google's Bard integrated into YouTube?",
#     "How is Alphabet's generative AI strategy impacting its revenue growth in 2023?",
#     'What are the key competitors to Alphabet in the generative AI market?']}),
#  (960,
#   {'queries': ['What are the best blue-chip stocks to invest in for the end of 2023?',
#     'How is Microsoft positioned in the AI market after the recent OpenAI developments?',
#     "What are Nvidia's earnings and stock performance trends for 2023?"]}),
#  (961,
#   {'queries': ['What is driving the recent growth of Watts Water Technologies stock in 2023?',
#     'How did Watts Water Technologies perform in the Asia-Pacific region this year?',
#     'What are the latest acquisitions by Watts Water Technologies and their impact on growth?']}),
#  (962,
#   {'queries': ['Is it too late to buy Adobe stock after its 80% surge in 2023?',
#     'How is Adobe performing compared to Autodesk and Salesforce in terms of stock valuation?',
#     "What are the potential risks of Adobe's acquisition of Figma and its impact on stock prices?"]}),
#  (963,
#   {'queries': ['What are the recent inflows for the Invesco NASDAQ 100 ETF (QQQM)?',
#     'How has QQQM performed compared to its 200 day moving average?',
#     'Which companies are the largest holdings in QQQM and how are they performing?']}),
#  (964,
#   {'queries': ["What were Autodesk's earnings for Q3 fiscal 2024?",
#     "How did Autodesk's subscription revenues perform in the latest report?",
#     'What is the fiscal 2024 guidance for Autodesk, Inc.?']}),
#  (965,
#   {'queries': ['What are the top software stocks to watch in November 2023?',
#     'How is Adobe performing in the software industry this year?',
#     'What trends are shaping the future of the computer software industry?']}),
#  (966,
#   {'queries': ['What is the latest performance of Woodward WWD shares in 2023?',
#     "How is Woodward's growth expected for fiscal 2024 and 2025?",
#     'What are the top-ranked stocks to consider alongside Woodward?']}),
#  (967,
#   {'queries': ['What is the iShares Expanded Tech-Software Sector ETF (IGV) and its performance in 2023?',
#     'Top holdings in the iShares Expanded Tech-Software Sector ETF (IGV)',
#     'Best ETFs for investing in technology software sector']}),
#  (968,
#   {'queries': ['What are the latest trends in the computer software industry?',
#     'How is Adobe performing in the current software market?',
#     'What are the top software stocks to consider for investment in 2023?']}),
#  (969,
#   {'queries': ['What are the best stocks to buy for 2024?',
#     'How did Apple perform in 2023 and what are its prospects for 2024?',
#     'Which companies are considered stock winners for the end of 2023?']}),
#  (970,
#   {'queries': ["What were Zoom's earnings for Q3 fiscal 2024?",
#     "How did Zoom's revenue from Enterprise customers perform in the latest quarter?",
#     "What is the latest guidance for Zoom's fiscal 2024 revenues and earnings?"]}),
#  (971,
#   {'queries': ["What is Adobe Systems' stock performance before the earnings report on December 13, 2023?",
#     "How does Adobe's upcoming earnings compare to analysts' estimates?",
#     'What is the Zacks Rank for Adobe Systems and what does it mean?']}),
#  (972,
#   {'queries': ['What is the Invesco NASDAQ 100 ETF (QQQM) and how does it compare to QQQ?',
#     'Best growth stocks to buy and hold for long-term investing in 2023',
#     'How is Intuit (INTU) performing as part of the QQQM ETF portfolio?']}),
#  (973,
#   {'queries': ['What are the latest earnings results for Cadence Design Systems in 2023?',
#     'How has Cadence Design Systems stock performed year to date?',
#     'What are the growth opportunities for Cadence Design Systems in the semiconductor market?']}),
#  (974,
#   {'queries': ["What is the latest news on Adobe's bid to acquire Figma?",
#     "How is the EU investigating Adobe's $20 billion purchase of Figma?",
#     'What are the implications of Adobe buying Figma for the design tool market?']}),
#  (975,
#   {'queries': ["What were Woodward Inc's earnings for Q4 fiscal 2023?",
#     "How did Woodward Inc's stock perform after their earnings announcement on Nov 16?",
#     'What is the fiscal 2024 outlook for Woodward Inc?']}),
#  (976,
#   {'queries': ["What is driving Itron's stock price increase in 2023?",
#     'Latest earnings report for Itron (ITRI) Q3 2023 highlights',
#     'Best investment opportunities in technology stocks like Itron and Adobe']}),
#  (977,
#   {'queries': ["What is Adobe's $20 billion bid for Figma about?",
#     "Latest news on Adobe's antitrust concerns in the EU",
#     'How will Adobe address regulatory issues with its Figma acquisition?']}),
#  (978,
#   {'queries': ['What are the latest options trading volumes for Upstart Holdings (UPST)?',
#     'How is Adobe Inc (ADBE) performing in options trading this month?',
#     'What is the current options activity for GameStop Corp (GME) and its upcoming expirations?']}),
#  (979,
#   {'queries': ["What is Adobe's $20 billion bid for Figma about?",
#     "Latest news on Adobe's antitrust concerns in the EU",
#     'How is Adobe planning to address EU regulatory issues with Figma acquisition?']}),
#  (980,
#   {'queries': ["What were DecisionPoint Systems' Q3 2023 earnings results?",
#     "How did DecisionPoint Systems' stock perform after their latest earnings report on Nov 14?",
#     'What is the revenue outlook for DecisionPoint Systems for full-year 2023?']}),
#  (981,
#   {'queries': ["What is Adobe's plan for its $20 billion Figma acquisition amid EU antitrust concerns?",
#     "Latest news on Adobe's antitrust warning regarding Figma deal",
#     'How is Adobe addressing regulatory issues for its Figma acquisition?']}),
#  (982,
#   {'queries': ['What is the Zacks Focus List and how does it work?',
#     'Top stocks to buy according to Zacks Premium service',
#     'Latest performance of Adobe Inc. stock in 2023']}),
#  (983,
#   {'queries': ["What is Adobe's $20 billion bid for Figma about?",
#     "Latest news on Adobe's acquisition of Figma and EU antitrust concerns",
#     "How could Adobe's deal with Figma affect the design tool market?"]}),
#  (984,
#   {'queries': ['What is Autodesk AI and how does it benefit designers?',
#     'Latest advancements in generative AI by Autodesk and its competitors',
#     'How is Autodesk AI transforming industries like construction and media?']}),
#  (985,
#   {'queries': ['What are the latest inflows for the Invesco NASDAQ 100 ETF (QQQM)?',
#     'How did Broadcom, Tesla, and Adobe perform recently in QQQM?',
#     'What is the 52-week price range for QQQM and its current trading price?']}),
#  (986,
#   {'queries': ['What are the top stocks that have outperformed the S&P 500 over the last decade?',
#     'How is NVIDIA performing in 2023 with AI demand?',
#     'What are the latest earnings expectations for Progressive and Adobe Systems?']}),
#  (987,
#   {'queries': ['What are the best tech stocks to invest in right now?',
#     'Adobe stock performance and recent news',
#     "Spotify's Q3 2023 earnings report details"]}),
#  (988,
#   {'queries': ["What is Adobe's stock price trend leading up to December 13, 2023 earnings report?",
#     "How do Adobe's earnings estimates compare to last year?",
#     'What are the best stocks to watch in the Computer and Technology sector right now?']}),
#  (989,
#   {'queries': ['How is Adobe Systems performing compared to other tech stocks in 2023?',
#     'What are the latest earnings estimates for IonQ, Inc.?',
#     'Which oil stocks are expected to have big gains in the coming months?']}),
#  (990,
#   {'queries': ["What are Google's latest updates in generative AI for 2023?",
#     'How is Alphabet expanding its AI-powered search capabilities globally?',
#     'What competitive features are Microsoft and Adobe introducing in their AI products?']}),
#  (991,
#   {'queries': ['What are the best GARP stocks to invest in right now?',
#     'How does the GARP investment strategy work?',
#     'Which stocks have performed well under the GARP strategy this year?']}),
#  (992,
#   {'queries': ["What were MACOM's earnings for Q4 fiscal 2023?",
#     "How did MACOM's revenue compare to estimates in Q4 2023?",
#     'What is the outlook for MACOM Technology Solutions in Q1 fiscal 2024?']}),
#  (993,
#   {'queries': ['Mettler-Toledo earnings report Q3 2023',
#     'Latest news on Mettler-Toledo sales performance',
#     "What are Mettler-Toledo's growth segments for 2023?"]}),
#  (994,
#   {'queries': ['What are the latest stock predictions for AMD and Adobe in 2023?',
#     'How is the S&P 500 performing year-to-date despite economic uncertainties?',
#     'What are the best stocks to watch for bullish moving average breakouts this month?']}),
#  (995,
#   {'queries': ['What is Singles Day and how did it start?',
#     'How does Singles Day spending compare to Black Friday?',
#     'What are the top products consumers buy during Singles Day in China?']}),
#  (996,
#   {'queries': ['What is the SPDR NYSE Technology ETF (XNTK) and how does it perform?',
#     'Best smart beta ETFs for technology investment in 2023',
#     'Latest updates on the NYSE Technology Index and its top holdings']}),
#  (997,
#   {'queries': ['What are the best software stocks to invest in right now?',
#     'How is Adobe using AI to enhance its products?',
#     'Why is Palo Alto Networks considered a strong cybersecurity investment?']}),
#  (998,
#   {'queries': ["What were Vishay Intertechnology's earnings for Q3 2023?",
#     "How did Vishay's revenue compare to estimates in the third quarter of 2023?",
#     'What is the outlook for Vishay Intertechnology in Q4 2023?']}),
#  (999,
#   {'queries': ["What are Adobe's latest financial results for Q3 2023?",
#     'Is Adobe stock a good investment after the recent upgrades from analysts?',
#     'How is Adobe leveraging AI technology in its products?']}),
#  ...]

# %%
# save query response to pickle
with open("data/query_response.pkl", "wb") as f:
    pickle.dump(query_response, f)

# %%
# load query response from pickle
with open("data/query_response.pkl", "rb") as f:
    query_response = pickle.load(f)

# %% [markdown]
# ## 3. Qrels Matching

# %%
def create_gold_qrels(query_response: List[Tuple[int, QueryResponse]], document_df: pd.DataFrame) -> pd.DataFrame:
    qrels = {"docno": [], 
            "qid": [], 
            "query": [], 
            "document": [],
            "label": []}
    qid = 0

    for response in query_response:
        for query in response[1]["queries"]:
            qrels["docno"].append(response[0])
            qrels["qid"].append(qid)
            qrels["query"].append(query)
            qrels["document"].append(document_df["Article"][response[0]])
            qrels["label"].append(1)
            qid += 1

    qrels = pd.DataFrame(qrels)

    non_duplicate_doc = document_df.drop_duplicates(subset="Article")
    non_dup_docno = non_duplicate_doc["docno"].values

    qrels = qrels[qrels["docno"].isin(non_dup_docno)]
    return qrels

non_duplicate_doc = document_df.drop_duplicates(subset="Article")
non_dup_docno = non_duplicate_doc["docno"].values

gold_qrels_df = create_gold_qrels(query_response, document_df)
display(gold_qrels_df.head())
gold_qrels_df.shape
# Out:
#    docno  qid                                              query  \
# 0      0    0     What are the top stocks to invest in for 2024?
# 1      0    1     How has Nvidia stock performed over the years?
# 2      0    2  What lessons can investors learn from holding ...
# 3      1    3  What are the latest analyst recommendations fo...
# 4      1    4      Is Apple's stock a good investment right now?
#
#                                             document  label
# 0  After an absolute disaster of a year in 2022, ...      1
# 1  After an absolute disaster of a year in 2022, ...      1
# 2  After an absolute disaster of a year in 2022, ...      1
# 3  When deciding whether to buy, sell, or hold a ...      1
# 4  When deciding whether to buy, sell, or hold a ...      1
# (50754, 5)

# %%
def select_documents_by_index(doc_scores: pd.DataFrame, 
                              index_percentile: int, 
                              top_n: int = 3) -> pd.DataFrame:
    threshold_index = int(len(doc_scores) * (index_percentile / 100.0))
    threshold_index = min(threshold_index, len(doc_scores) - 1)
    selected_docs = doc_scores.iloc[threshold_index:threshold_index + top_n]
    return selected_docs


def match_negative_query(scorer: BM25Okapi, 
                             query: str, 
                             documents: List[str], 
                             index_percentiles: List[int]=[90, 95, 99],
                             debug=False,
                             qid=None) -> Dict[str, Any]:
    selected_docs_by_percentile = {}
    
    tokenized_query = query.split()

    scores = scorer.get_scores(tokenized_query)
    doc_scores = pd.DataFrame({"document": documents, "score": scores})

    sorted_doc_scores = doc_scores.sort_values(by="score", ascending=False).reset_index(drop=True)
    for percentile in index_percentiles:
        selected_docs = select_documents_by_index(sorted_doc_scores, index_percentile=percentile, top_n=3)
        if debug:
            print(selected_docs)
        selected_docs_by_percentile[percentile] = selected_docs["document"].values 

    if qid is None:
        return {"negative_documents": [doc for docs in selected_docs_by_percentile.values() for doc in docs]}
    
    return {"qid": qid, 
            "negative_documents": [doc for docs in selected_docs_by_percentile.values() for doc in docs]}

async def bm25_qrels_matcher(gold_qrels_df: pd.DataFrame, documents: List[str]) -> pd.DataFrame:
    documents = non_duplicate_doc["Article"].values
    tokenized_documents = [doc.split() for doc in documents]
    bm25_scorer = BM25Okapi(tokenized_documents)

    loop = asyncio.get_running_loop()

    tasks = [
        loop.run_in_executor(
            None,
            match_negative_query,
            bm25_scorer,
            gold_qrels_df["query"].iloc[idx],
            documents,
            [90, 95, 99],
            False,
            gold_qrels_df["qid"].iloc[idx],
        )
        for idx in range(len(gold_qrels_df))
    ]

    responses = []
    for response in tqdm(asyncio.as_completed(tasks), total=len(tasks), desc="Processing"):
        responses.append(await response)

    return responses

# %%
documents = non_duplicate_doc["Article"].values

qrels_response = await bm25_qrels_matcher(gold_qrels_df=gold_qrels_df, documents=documents)
# Out:
# Processing: 100%|██████████| 50754/50754 [1:12:37<00:00, 11.65it/s]

# %%
qrels = {"qid": [], "query": [], "docno": [], "document": [], "label": []}

for response in tqdm(qrels_response, total=len(qrels_response)):
    qid = response["qid"]

    gold_qrel = gold_qrels_df[gold_qrels_df["qid"] == qid].iloc[0]
    qrels["qid"].append(qid)
    qrels["query"].append(gold_qrel["query"])
    qrels["docno"].append(gold_qrel["docno"])
    qrels["document"].append(gold_qrel["document"])
    qrels["label"].append(1)

    for doc in response["negative_documents"]:
        docno = non_duplicate_doc[non_duplicate_doc["Article"] == doc]["docno"].values[0]

        qrels["qid"].append(qid)
        qrels["query"].append(gold_qrel["query"])
        qrels["docno"].append(docno)
        qrels["document"].append(doc)
        qrels["label"].append(0)

qrels_df = pd.DataFrame(qrels)
# Out:
# 100%|██████████| 50754/50754 [13:08<00:00, 64.34it/s]

# %%
qrels_df
# Out:
#           qid                                              query  docno  \
# 0           1     How has Nvidia stock performed over the years?      0
# 1           1     How has Nvidia stock performed over the years?  13854
# 2           1     How has Nvidia stock performed over the years?  13917
# 3           1     How has Nvidia stock performed over the years?   1304
# 4           1     How has Nvidia stock performed over the years?  18893
# ...       ...                                                ...    ...
# 507535  56967  What is Wedbush's latest recommendation for Zs...  13507
# 507536  56967  What is Wedbush's latest recommendation for Zs...   9921
# 507537  56967  What is Wedbush's latest recommendation for Zs...  11524
# 507538  56967  What is Wedbush's latest recommendation for Zs...  16031
# 507539  56967  What is Wedbush's latest recommendation for Zs...  11138
#
#                                                  document  label
# 0       After an absolute disaster of a year in 2022, ...      1
# 1       Looking today at week-over-week shares outstan...      0
# 2       Looking today at week-over-week shares outstan...      0
# 3       Looking today at week-over-week shares outstan...      0
# 4       Shares of Elbit Systems Ltd. (ESLT) declined 2...      0
# ...                                                   ...    ...
# 507535  Yelp Inc. YELP shares gained 4.5% during Thurs...      0
# 507536  Nordson Corp.’s (NDSN) shares surged 3.9% afte...      0
# 507537  Nov 20 (Reuters) - Wall Street's main indexes ...      0
# 507538  Consumer stocks were gaining late Thursday aft...      0
# 507539  Tech stocks were mixed Friday afternoon with t...      0
#
# [507540 rows x 5 columns]

# %% [markdown]
# ## 4. Dataset Splitting

# %%
np.random.seed(42)

TRAIN_SIZE = 6000
VAL_SIZE = 2000
TEST_SIZE = 2000

qids = qrels_df["qid"].unique()

train_qids = np.random.choice(qids, TRAIN_SIZE, replace=False)
remaining_qids = np.setdiff1d(qids, train_qids)

val_qids = np.random.choice(remaining_qids, VAL_SIZE, replace=False)
remaining_qids = np.setdiff1d(remaining_qids, val_qids)

test_qids = np.random.choice(remaining_qids, TEST_SIZE, replace=False)

train_qrels_df = qrels_df[qrels_df["qid"].isin(train_qids)]
val_qrels_df = qrels_df[qrels_df["qid"].isin(val_qids)]
test_qrels_df = qrels_df[qrels_df["qid"].isin(test_qids)]

train_qrels_df.shape, val_qrels_df.shape, test_qrels_df.shape
# Out:
# ((60000, 5), (20000, 5), (20000, 5))

# %%
# save qrels to parquet
train_qrels_df.to_parquet("data/train_qrels.parquet", index=False)
val_qrels_df.to_parquet("data/val_qrels.parquet", index=False)
test_qrels_df.to_parquet("data/test_qrels.parquet", index=False)
